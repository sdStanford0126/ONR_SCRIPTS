# %%
import numpy as np
import matplotlib
matplotlib.rc('text', usetex=True)
import matplotlib.pyplot as plt
plt.rcParams.update({
    'axes.linewidth':     1.5,
    'xtick.major.width' : 1.5,
    'ytick.major.width' : 1.5,
    "font.family" : "serif",
    "text.latex.preamble" : r"\usepackage{amsmath} \usepackage{times} \usepackage{fourier} \usepackage{bm}",
    "font.size" : 14,
    "legend.fontsize" : 12})
import sys
import os
import scipy.io as io

# %% [markdown]
# This goal of this script is to read the port probes data and organize it back into individual ports
# The data format for the .pxyz file, which contains all the position of the probes in the order they are recorded
# |col1 | col2| col3 | col4|
# |-----|-----|------|-----|
# |indices|x|y|z|
#
#
# Note that indices indicates the order of the probes as provided in the original probe.txt file, the .pcd files probes does **NOT** follow the order of the original txt file, it follows the order in the .pxyz file, requiring the use of indices if we want to recover the original order as provided!

# %%
#specify the working directories
in_dir = "~/pcprobes_ports/" #specify the data directory
out_dir = "./"

# %%
def processPxyz(prefix):
    #process .pxyz file from the given file name, fname needs to include path
    fname = ind_dir + 
    data = np.loadtxt(fname,skiprows=1,delimiter=" ") #skip first row which is header
    Nprobes = data.shape[0] #assuming this reads in colmuns
    indices = data[:,0]
    xyz     = data[:,4] #grab the xyz

    #TODO: reorganize xyz to align with indices #assume no misses for now
    #how to do this?
    return Nprobes,indices,xyz
